# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/ozcangundes/mt5-small-turkish-summarization
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/ozcangundes/mt5-small-turkish-summarization)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %% [markdown]
# ## 1. Pipeline ile kullanma
#
# Bu model özelikle haber özetlemek için geliştirilmiş bir modeldir.
# Model arka planda indirilir. Hehangi bir vektörleştirme veya ön işleme gerekmeden modele girdi verilir çıktı alınır.
#
# HF Token gerektirmez.
#
# Use a pipeline as a high-level helper
# Warning: Pipeline type "summarization" is no longer supported in transformers v5.
# You must load the model directly (see below) or downgrade to v4.x with:
# '`pip install "transformers<5.0.0`'

# %%
# !pip install "transformers<5.0.0"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 120.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 54.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.20.1
#     Uninstalling huggingface_hub-1.20.1:
#       Successfully uninstalled huggingface_hub-1.20.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.12.1
#     Uninstalling transformers-5.12.1:
#       Successfully uninstalled transformers-5.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 6.19.0 requires huggingface-hub<2.0,>=1.2.0, but you have huggingface-hub 0.36.2 which is incompatible.
# ...

# %%
from transformers import pipeline
pipe = pipeline(model="ozcangundes/mt5-small-turkish-summarization")
# Out:
# config.json:   0%|          | 0.00/648 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/388 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# ...

# %%
text="""
Türkiye, resmî adıyla Türkiye Cumhuriyeti, topraklarının büyük bölümü Anadolu'da, küçük bir bölümü ise Balkan Yarımadası'nın uzantısı olan Trakya'da yer alan kıtalararası bir ülkedir. Kuzeybatıda Bulgaristan, batıda Yunanistan, kuzeydoğuda Gürcistan, doğuda Ermenistan, Nahçıvan ve İran, güneydoğuda ise Irak ve Suriye komşusudur.
"""

# %%
pipe(text)
# Out:
# [{'summary_text': "Türkiye Cumhuriyeti , topraklarının büyük bölümü Anadolu'da , küçük bir bölümü ise Balkan Yarımadası'nın uzantısı olan Trakya'da yer alan kıtalararası bir ülkedir ."}]

# %%
# Sentiment analizi (Türkçe destekli model)
from transformers import pipeline
clf = pipeline("sentiment-analysis", model="savasy/bert-base-turkish-sentiment-cased")
clf("Bu eğitim harikaydı, çok şey öğrendim.")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/442M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/263k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# [{'label': 'positive', 'score': 0.9924688935279846}]

# %%
sentiment_dataset = [
    # Pozitif Yorumlar (50 Adet)
    "Eğitim içeriği son derece doyurucu ve pratik uygulamalarla desteklenmişti.",
    "Hocanın konuya hakimiyeti ve anlatım tarzı gerçekten mükemmeldi.",
    "Bu kurstan sonra projelerimde LLM entegrasyonunu çok daha rahat yapabiliyorum.",
    "Deep learning konuları ancak bu kadar akıcı ve net anlatılabilirdi.",
    "Teorik altyapı ile kodlama pratikleri harika bir dengede sunulmuş.",
    "Zaman yönetimini ve interaktif soru-cevap seanslarını çok başarılı buldum.",
    "Eğitim sayesinde veri analizi süreçlerindeki eksiklerimi tamamen kapattım.",
    "Anlatım dili çok duru, karmaşık algoritmalar bile kolayca anlaşılıyor.",
    "Kullanılan kod örnekleri güncel production senaryolarına çok uygundu.",
    "Kesinlikle zaman ve emek yatırımına değer bir organizasyon olmuş.",
    "Yapay zeka modellerinin ince ayar süreçleri çok detaylı aktarıldı.",
    "Eğitmene destekleri ve yapıcı geri bildirimleri için teşekkür ederim.",
    "Sektördeki güncel gelişmeleri içeren vizyoner bir eğitim programıydı.",
    "Derste paylaşılan kaynaklar ve repolar kütüphanemde yerini aldı bile.",
    "Zorlu matematiksel formüller görselleştirilerek harika somutlaştırılmış.",
    "Eğitimin interaktif yapısı odaklanmayı son derece kolaylaştırdı.",
    "Müfredat tam anlamıyla güncel trendleri yakalayacak şekilde tasarlanmış.",
    "Uygulamalı laboratuvar çalışmaları konuyu pekiştirmek için çok faydalıydı.",
    "Emeği geçen herkese teşekkürler, kariyerim için dönüm noktası oldu.",
    "Sıfırdan ileri seviyeye giden rota çok mantıklı kurgulanmış.",
    "Hocanın tecrübesini her cümlesinde hissetmek mümkündü.",
    "Özellikle NLP bölümündeki pratik yaklaşımlar ufkumu açtı.",
    "Organizasyonun başından sonuna kadar her detay profesyonelceydi.",
    "Verilen ödevler ve projeler gerçek hayat senaryolarını aratmıyordu.",
    "Eğitim beklentilerimin çok üzerinde bir kaliteye sahipti.",
    "Anlatılan tekniklerin iş hayatındaki karşılığını görmek harikaydı.",
    "Konular arasındaki geçişler son derece organik ve akıcıydı.",
    "Kurs materyallerinin kalitesi ve sunumlar çok profesyonel hazırlanmış.",
    "Bu fiyata bu düzeyde bir derinlik bulmak gerçekten şaşırtıcı.",
    "Eğitmenin sabrı ve tüm sorulara detaylı yanıt vermesi harikuladeydi.",
    "Pipeline mimarilerini bu kadar net anlatan başka bir kaynak görmedim.",
    "Eğitim sonrasındaki topluluk desteği de en az dersler kadar değerli.",
    "Karmaşık mimarilerin sadeleştirilerek anlatılması öğrenmeyi hızlandırdı.",
    "Her modül bir sonraki konuya harika bir zemin hazırlıyordu.",
    "Sektör profesyonelleri için kaçırılmaması gereken bir kaynak olmuş.",
    "Modelleme aşamasındaki ince ipuçları altın değerindeydi.",
    "Eğitim boyunca motivasyonumuz bir an bile düşmedi.",
    "Pratik hileler ve debug yöntemleri anlatımı çok zenginleştirmiş.",
    "Konseptlerin mantığını kavramak adına mükemmel bir metodoloji izlenmiş.",
    "Eğitim bittiğinde portföyüme ekleyebileceğim somut çıktılarım vardı.",
    "Akademik derinlik ile sektörel tecrübe harika harmanlanmış.",
    "Sınıf içi dinamikler ve bilgi paylaşımı üst düzeydeydi.",
    "Zor konuların bu kadar eğlenceli anlatılabileceğini tahmin etmezdim.",
    "Eğitim süresi içeriğin hakkını verecek şekilde optimize edilmiş.",
    "Sunum slaytları bile tek başına bir başvuru kaynağı niteliğinde.",
    "Veri madenciliği tekniklerine bakış açımı tamamen değiştiren bir kurs.",
    "Dersteki canlı kodlama seansları hata yönetimini öğrenmek için harikaydı.",
    "Verilen emek ve gösterilen özen kendisini hemen belli ediyor.",
    "Bu eğitimle birlikte workflow süreçlerimizi yeniden yapılandırdık.",
    "Katıldığım en verimli ve bilgi yoğun yapay zeka eğitimiydi.",

    # Negatif Yorumlar (50 Adet)
    "Eğitim içeriği çok yüzeysel kalmış, derinlemesine bilgi verilmedi.",
    "Slaytlardan doğrudan okuma yapılması anlatımı çok sıkıcı hale getirdi.",
    "Süre yönetimi kötüydü, son konular aceleye getirilip geçiştirildi.",
    "Soru-cevap kısmında sorulara net ve tatmin edici yanıtlar alamadık.",
    "Kod örnekleri güncel kütüphane versiyonlarıyla çalışmıyor, hatalıydı.",
    "Teorik kısımlar çok uzun tutulmuş, uygulamaya neredeyse hiç zaman kalmadı.",
    "Anlatım dili çok monoton olduğu için odağı korumak imkansızdı.",
    "Eğitimin vaat ettiği müfredat ile anlatılanlar birbiriyle uyuşmuyor.",
    "Ses kalitesi ve teknik altyapı eğitim boyunca ciddi sorun yarattı.",
    "Giriş seviyesi olarak belirtilmesine rağmen konular çok karmaşık başladı.",
    "Bu bütçeye karşılık alınan verim kesinlikle yeterli değil.",
    "Ders materyalleri ve kod repoları çok düzensiz paylaşıldı.",
    "İleri düzey bir eğitim beklentisiyle geldim ama temel seviyeyi geçemedi.",
    "Eğitmen konuya hakim görünmüyordu, sürekli duraksayarak anlattı.",
    "Örnek senaryolar gerçek iş hayatından çok uzak ve yapay kalmış.",
    "Eğitim salonunun fiziki şartları ve konforu oldukça yetersizdi.",
    "Konular arasında hiçbir mantıksal bağ ve akış kurgulanmamış.",
    "Paylaşılan dökümanlardaki yazım hataları ve kopukluklar rahatsız ediciydi.",
    "Pratik uygulamalar çok basitti, internetteki hazır scriptlerden farkı yoktu.",
    "Katılımcı sayısı çok fazla olduğu için interaktif bir ortam oluşmadı.",
    "Zamanımı daha verimli kaynaklarla değerlendirebilirdim, hayal kırıklığı.",
    "Eğitim boyunca sürekli reklam yapılması konsantrasyonu bozdu.",
    "Ödevlerin geri bildirim süreçleri tamamen ihmal edildi.",
    "Algoritmaların matematiksel arka planı tamamen es geçilmiş.",
    "Organizasyon ekibinin koordinasyonsuzluğu süreçleri çok aksattı.",
    "Ders içi canlı kodlamalarda çok fazla zaman kaybı yaşandı.",
    "Kullanılan veri setleri çok küçük ve günümüz trendlerinden uzaktı.",
    "Eğitmenin üslubu ve yaklaşımı profesyonellikten uzaktı.",
    "Aynı konular sürekli tekrar edilerek vakit doldurulmaya çalışılmış.",
    "Eğitim sonrası destek ve topluluk vaatleri havada kaldı.",
    "Görsel materyaller ve sunum tasarımı çok özensiz hazırlanmış.",
    "Sorulan spesifik sorular 'sonra bakıp döneceğim' denilerek geçiştirildi.",
    "Müfredat çok eski teknikler üzerine kurulmuş, yenilikçi hiçbir şey yok.",
    "Eğitim ortamındaki gürültü ve organizasyon hataları odaklanmayı engelledi.",
    "Uygulama videolarının çözünürlüğü kodları okumak için çok düşüktü.",
    "Verilen süre içerisinde bu kadar yoğun konunun işlenmesi imkansızdı.",
    "Kendi başıma dokümantasyon okuyarak çok daha hızlı öğrenebilirdim.",
    "Eğitmen gelen eleştirilere karşı oldukça savunmacı bir tavır sergiledi.",
    "Kursun takvimi sürekli değiştirildi ve planlama yapmak zorlaştı.",
    "Pipeline kurulumlarında yaşanan teknik aksaklıklar dersi böldü.",
    "Anlatılan yöntemlerin maliyet ve performans analizlerine hiç değinilmedi.",
    "Örnekler sadece hazır kütüphane fonksiyonlarını çağırmaktan ibaretti.",
    "Eğitim içeriği günümüz sektör ihtiyaçlarını kesinlikle karşılamıyor.",
    "Katılımcıların seviyeleri çok farklı olduğu için ortak bir ritim yakalanamadı.",
    "Derslerin bölünmesi ve odak kaybı yüzünden verim sıfıra indi.",
    "Kaynak kodların paylaşılacağı söylendi ancak eğitim bitmesine rağmen iletilmedi.",
    "Temel istatistik bilgisi verilmeden doğrudan modele geçilmesi hataydı.",
    "Anlatım çok kopuktu, bir konudan diğerine mantıksız geçişler yapıldı.",
    "Eğitimin pratik değeri kağıt üzerindeki vaatlerinin çok gerisinde.",
    "Paranızın ve zamanınızın karşılığını vermeyen bir organizasyon."
]

# %%
for yorum in sentiment_dataset:
    print(clf(yorum))
# Out:
# [transformers] You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# [{'label': 'positive', 'score': 0.9786390066146851}]
# [{'label': 'positive', 'score': 0.9895037412643433}]
# [{'label': 'positive', 'score': 0.9930520057678223}]
# [{'label': 'positive', 'score': 0.9886215329170227}]
# [{'label': 'positive', 'score': 0.9897394776344299}]
# [{'label': 'positive', 'score': 0.9929198622703552}]
# [{'label': 'positive', 'score': 0.953288197517395}]
# [{'label': 'positive', 'score': 0.9921010136604309}]
# [{'label': 'positive', 'score': 0.7590299248695374}]
# [{'label': 'negative', 'score': 0.735260546207428}]
# [{'label': 'positive', 'score': 0.7496921420097351}]
# [{'label': 'positive', 'score': 0.9621338248252869}]
# [{'label': 'positive', 'score': 0.9908345937728882}]
# [{'label': 'positive', 'score': 0.9700175523757935}]
# [{'label': 'positive', 'score': 0.9932138919830322}]
# ...

# %%
neutral_comments = [
    # Nötr Yorumlar (20 Adet)
    "Ankara Türkiyenin başkentidir!",
    "İçerik ne çok iyi ne çok kötüydü, beklentiyi karşılıyor.",
    "Konular anlatıldı ancak bazı bölümler daha detaylı olabilirdi.",
    "Ortalama bir eğitim, ne eksik ne fazla diyebilirim.",
    "Teorik bilgi ve uygulama dengesi normal düzeydeydi.",
    "Eğitmenden aldığım yanıtlar standart düzeydeydi, fena değildi.",
    "Benzer içerikleri internette de bulmak mümkün, sıradan bir kurstu.",
    "Eğitim süresi içeriğe göre tam sınırdaydı, idare eder.",
    "Sunum slaytları sade ve anlaşılırdı, ekstra bir detay yoktu.",
    "Katılımcı profili ve dersin işleniş hızı ortalamaydı.",
    "Sektördeki diğer eğitimlerle benzer nitelikte bir program olmuş.",
    "Uygulama örnekleri basitti ancak konuyu anlamaya yetiyordu.",
    "Mekan ve teknik altyapı standart beklentileri karşılıyordu.",
    "Eğitimden ne çok büyük bir kazanım sağladım ne de zaman kaybettim.",
    "Ders takvimine uyuldu, planlandığı gibi başlayıp bitti.",
    "Kaynak kodlar paylaşıldı, inceleyip kararı kendiniz verebilirsiniz.",
    "Anlatım hızı ne yavaştı ne de hızlı, normal bir ritimde ilerledi.",
    "Giriş seviyesi için uygun, ileri seviye için nötr kalınabilecek bir kurs.",
    "Eğitimin içeriği vaat edilen başlıkları temel düzeyde kapsıyordu.",
    "Genel olarak nötr bir deneyimdi, eksikleri de vardı artıları da."
]

# %%
for yorum in neutral_comments:
        print(clf(yorum))
# Out:
# [{'label': 'positive', 'score': 0.9880546927452087}]
# [{'label': 'negative', 'score': 0.790285050868988}]
# [{'label': 'negative', 'score': 0.9808738827705383}]
# [{'label': 'negative', 'score': 0.8532111048698425}]
# [{'label': 'negative', 'score': 0.9199491739273071}]
# [{'label': 'negative', 'score': 0.9984751343727112}]
# [{'label': 'negative', 'score': 0.9984386563301086}]
# [{'label': 'positive', 'score': 0.5093802809715271}]
# [{'label': 'negative', 'score': 0.9308809638023376}]
# [{'label': 'negative', 'score': 0.9458056688308716}]
# [{'label': 'negative', 'score': 0.9939845204353333}]
# [{'label': 'negative', 'score': 0.9984629154205322}]
# [{'label': 'negative', 'score': 0.9926750063896179}]
# [{'label': 'negative', 'score': 0.998775064945221}]
# [{'label': 'positive', 'score': 0.5901424288749695}]
# [{'label': 'negative', 'score': 0.9592525362968445}]
# [{'label': 'negative', 'score': 0.6482011079788208}]
# [{'label': 'negative', 'score': 0.8078615665435791}]
# ...
